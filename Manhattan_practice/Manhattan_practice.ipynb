# %% [markdown]
# # 利用“qqman”绘制曼哈顿图

# %% [markdown]
# ## 加载qqman 安装包

# %%
library("qqman")

# %% [markdown]
# ## 读取GWASRESULT的数据

# %%
dataset <- read.csv("GAPIT.MLM.ADG.GWAS.Results1.csv")

# %% [markdown]
# ## 利用读取的数据做曼哈顿图

# %%
manhattan(dataset,col=c("#A4D3EE","#DDA0DD"))
# Out:
# plot without title
